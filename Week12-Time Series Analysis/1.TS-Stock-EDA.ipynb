# %%
from Descriptive import Descriptive

# %%
obj=Descriptive()

# %%
import yfinance as yf
import datetime as dt

start = dt.datetime(2021,6,1)
end = dt.datetime(2022,1,5)

stk_data = yf.download("TATACOFFEE13_21.NS", start=start, end=end)

print(stk_data)
# Out:
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: TATACOFFEE13_21.NS"}}}
# $TATACOFFEE13_21.NS: possibly delisted; no timezone found
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['TATACOFFEE13_21.NS']: possibly delisted; no timezone found
# Empty DataFrame
# Columns: [(Adj Close, TATACOFFEE13_21.NS), (Close, TATACOFFEE13_21.NS), (High, TATACOFFEE13_21.NS), (Low, TATACOFFEE13_21.NS), (Open, TATACOFFEE13_21.NS), (Volume, TATACOFFEE13_21.NS)]
# Index: []

# %%
stk_data.info()
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 0 entries
# Data columns (total 6 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   (Adj Close, TATACOFFEE13_21.NS)  0 non-null      float64
#  1   (Close, TATACOFFEE13_21.NS)      0 non-null      float64
#  2   (High, TATACOFFEE13_21.NS)       0 non-null      float64
#  3   (Low, TATACOFFEE13_21.NS)        0 non-null      float64
#  4   (Open, TATACOFFEE13_21.NS)       0 non-null      float64
#  5   (Volume, TATACOFFEE13_21.NS)     0 non-null      float64
# dtypes: float64(6)
# memory usage: 0.0 bytes

# %%
stk_data
# Out:
# Empty DataFrame
# Columns: [(Adj Close, TATACOFFEE13_21.NS), (Close, TATACOFFEE13_21.NS), (High, TATACOFFEE13_21.NS), (Low, TATACOFFEE13_21.NS), (Open, TATACOFFEE13_21.NS), (Volume, TATACOFFEE13_21.NS)]
# Index: []

# %%
low=stk_data["Low"]

# %%
dataset=stk_data
quan,qual=obj.segreQuanQual(dataset)
# Out:
# The Quantitative Data: [('Adj Close', 'TATACOFFEE13_21.NS'), ('Close', 'TATACOFFEE13_21.NS'), ('High', 'TATACOFFEE13_21.NS'), ('Low', 'TATACOFFEE13_21.NS'), ('Open', 'TATACOFFEE13_21.NS'), ('Volume', 'TATACOFFEE13_21.NS')]
# The Qualtitative Data []

# %%
class AnalysisClass:
    def descriptive_Analysis(self, dataset, quan):
        import pandas as pd
        description = dataset[quan].describe()
        return description

# %%
# create object of AnalysisClass
analysis_obj = AnalysisClass()

# call method and store result
des_data = analysis_obj.descriptive_Analysis(dataset, quan)

# print result
print(des_data)
# Out:
# Price           Adj Close              Close               High  \
# Ticker TATACOFFEE13_21.NS TATACOFFEE13_21.NS TATACOFFEE13_21.NS
# count                 0.0                0.0                0.0
# mean                  NaN                NaN                NaN
# std                   NaN                NaN                NaN
# min                   NaN                NaN                NaN
# 25%                   NaN                NaN                NaN
# 50%                   NaN                NaN                NaN
# 75%                   NaN                NaN                NaN
# max                   NaN                NaN                NaN
#
# Price                 Low               Open             Volume
# Ticker TATACOFFEE13_21.NS TATACOFFEE13_21.NS TATACOFFEE13_21.NS
# count                 0.0                0.0                0.0
# mean                  NaN                NaN                NaN
# std                   NaN                NaN                NaN
# min                   NaN                NaN                NaN
# 25%                   NaN                NaN                NaN
# 50%                   NaN                NaN                NaN
# 75%                   NaN                NaN                NaN
# max                   NaN                NaN                NaN

# %%
des_data["Low"]
# Out:
# Ticker  TATACOFFEE13_21.NS
# count                  0.0
# mean                   NaN
# std                    NaN
# min                    NaN
# 25%                    NaN
# 50%                    NaN
# 75%                    NaN
# max                    NaN

# %%
des_data["High"]
# Out:
# Ticker  TATACOFFEE13_21.NS
# count                  0.0
# mean                   NaN
# std                    NaN
# min                    NaN
# 25%                    NaN
# 50%                    NaN
# 75%                    NaN
# max                    NaN

# %%
import numpy as np

# %%
dataset = pd.read_csv('Tatacoffee13_21.csv')
dataset.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 dataset = pd.read_csv('Tatacoffee13_21.csv')
#       2 dataset.head()
#
# NameError: name 'pd' is not defined

# %%
get_pdf_probability(dataset["Low"],219,230)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 get_pdf_probability(dataset["Low"],219,230)
#
# NameError: name 'get_pdf_probability' is not defined

# %%
def stdNBgraph(dataset):
        # Coverted to standard Normal Distribution
    import seaborn as sns
    mean=dataset.mean()
    std=dataset.std()

    values=[i for i in dataset]

    z_score=[((j-mean)/std) for j in values]

    sns.distplot(z_score,kde=True)

    sum(z_score)/len(z_score)
    #z_score.std()

# %%
stdNBgraph(dataset["Low"])

# %%
def freqTable(columnName,dataset):
    import pandas as pd
    frq=pd.DataFrame()
    frq["Unique_Values"]=dataset[columnName].value_counts().index
    frq["Frequency"]=dataset[columnName].value_counts().values
    frq["Relative_Fre"]=dataset[columnName].value_counts().values/len(dataset[columnName])*100
    frq["Cumulative"]=frq["Relative_Fre"].cumsum()
    return frq

# %%
freqTable("Low",dataset)
# Out:
#      Unique_Values  Frequency  Relative_Fre  Cumulative
# 0           196.00          3      1.986755    1.986755
# 1           203.05          2      1.324503    3.311258
# 2           207.15          2      1.324503    4.635762
# 3           186.30          2      1.324503    5.960265
# 4           210.20          2      1.324503    7.284768
# ..             ...        ...           ...         ...
# 133         199.35          1      0.662252   97.350993
# 134         208.30          1      0.662252   98.013245
# 135         202.05          1      0.662252   98.675497
# 136         175.60          1      0.662252   99.337748
# 137         173.75          1      0.662252  100.000000
#
# [138 rows x 4 columns]

# %%
freqTable("High",dataset)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 freqTable("High",dataset)
#
# NameError: name 'freqTable' is not defined

# %%
fh=freqTable("High",dataset)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 fh=freqTable("High",dataset)
#
# NameError: name 'freqTable' is not defined

# %%
fh.sort_values(by="Frequency",ascending=False)
# Out:
#      Unique_Values  Frequency  Relative_Fre  Cumulative
# 0           193.95          2      1.315789    1.315789
# 6           207.80          2      1.315789    9.210526
# 1           209.50          2      1.315789    2.631579
# 10          214.70          2      1.315789   14.473684
# 8           218.70          2      1.315789   11.842105
# ..             ...        ...           ...         ...
# 47          202.00          1      0.657895   38.815789
# 46          192.50          1      0.657895   38.157895
# 45          187.50          1      0.657895   37.500000
# 44          186.50          1      0.657895   36.842105
# 140         190.00          1      0.657895  100.000000
#
# [141 rows x 4 columns]

# %%
fhs=fh[fh["Frequency"]==2]["Unique_Values"].sort_values(ascending=False)

# %%
fhs
# Out:
# 8     218.70
# 3     218.30
# 10    214.70
# 7     213.00
# 1     209.50
# 6     207.80
# 9     206.00
# 2     204.05
# 0     193.95
# 4     189.00
# 5     178.70
# Name: Unique_Values, dtype: float64
