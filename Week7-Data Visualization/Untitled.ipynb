# %%
import pandas as pd
import numpy as np
from pandas.api.types import CategoricalDtype
from plotnine import *
from plotnine.data import mpg
# %matplotlib inline

(ggplot(mpg)         # defining what data to use
 + aes(x='class')    # defining what variable to use
 + geom_bar(size=20) # defining the type of plot to use
)
# Out:
# <ggplot: (28635747)>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('Placement_Data_Full_Class.csv')

# %%
import pandas as pd
import numpy as np
from pandas.api.types import CategoricalDtype
from plotnine import *
from plotnine.data import mpg
# %matplotlib inline

(ggplot(dataset)         # defining what data to use
 + aes(x='gender')    # defining what variable to use
 + geom_bar(size=20) # defining the type of plot to use
)
# Out:
# <ggplot: (28668150)>

# %%
(ggplot(dataset)
 + aes(x='gender')
 + geom_bar(size=20)
 + coord_flip()        # flipping the x- and y-axes
 + labs(title='Number of Male and Female', x='Gender', y='count') # customizing labels
)
# Out:
# <ggplot: (-9223372036825908336)>

# %%
(ggplot(dataset)
 + aes(x='gender',y='ssc_p',fill='ssc_b')
 + geom_boxplot(size=20)
       # flipping the x- and y-axes
 + labs(title='Number of Male and Female', x='Gender', y='count') # customizing labels
)
# Out:
# <ggplot: (-9223372036825905983)>

# %%
(ggplot(dataset, aes(x='continent', y='lifeExp', fill='continent')) +
        geom_boxplot()
)
