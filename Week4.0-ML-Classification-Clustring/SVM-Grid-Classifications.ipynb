# %%
#importing the Libraies

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('Social_Network_Ads.csv')

# %%
dataset
# Out:
#      Age  Gender_male  Estimated_Salary  Actual  Predicted
# 0     30         True             87000       0          0
# 1     38        False             50000       0          0
# 2     35         True             75000       0          0
# 3     30        False             79000       0          0
# 4     35        False             50000       0          0
# ..   ...          ...               ...     ...        ...
# 129   29         True            148000       1          1
# 130   26        False             15000       0          0
# 131   60         True             42000       1          1
# 132   24         True             19000       0          0
# 133   42         True            149000       1          1
#
# [134 rows x 5 columns]

# %%
dataset
# Out:
#      Age  Gender_male  Estimated_Salary  Actual  Predicted
# 0     30         True             87000       0          0
# 1     38        False             50000       0          0
# 2     35         True             75000       0          0
# 3     30        False             79000       0          0
# 4     35        False             50000       0          0
# ..   ...          ...               ...     ...        ...
# 129   29         True            148000       1          1
# 130   26        False             15000       0          0
# 131   60         True             42000       1          1
# 132   24         True             19000       0          0
# 133   42         True            149000       1          1
#
# [134 rows x 5 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#      Age  Gender_male  Estimated_Salary  Actual  Predicted
# 0     30         True             87000       0          0
# 1     38        False             50000       0          0
# 2     35         True             75000       0          0
# 3     30        False             79000       0          0
# 4     35        False             50000       0          0
# ..   ...          ...               ...     ...        ...
# 129   29         True            148000       1          1
# 130   26        False             15000       0          0
# 131   60         True             42000       1          1
# 132   24         True             19000       0          0
# 133   42         True            149000       1          1
#
# [134 rows x 5 columns]

# %%
indep=dataset[['Age', 'Gender_male', 'Estimated_Salary']]
dep=dataset['Predicted']

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.svm import SVC

# %%
#https://scikit-learn.org/stable/modules/model_evaluation.html#scoring-parameter

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {'kernel':['linear','rbf','poly','sigmoid'],
             'gamma':['auto','scale'],
             'C':[10,100,1000,2000,3000]} 



grid = GridSearchCV(SVC(probability=True), param_grid, refit = True, verbose = 3,cv=5,n_jobs=-1,scoring='f1_weighted') 
   
# fitting the model for grid search 
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# GridSearchCV(cv=5, estimator=SVC(probability=True), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000, 3000],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['linear', 'rbf', 'poly', 'sigmoid']},
#              scoring='f1_weighted', verbose=3)

# %%
# print best parameter after tuning 
#print(grid.best_params_) 
re=grid.cv_results_
#print(re)
grid_predictions = grid.predict(X_test) 
   

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, grid_predictions)



# print classification report 
from sklearn.metrics import classification_report
clf_report = classification_report(y_test, grid_predictions)

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(y_test,grid_predictions,average='weighted')
print("The f1_macro value for best parameter {}:".format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value for best parameter {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}: 0.9774605234696085

# %%
print("The confusion Matrix:\n",cm)
# Out:
# The confusion Matrix:
#  [[33  0]
#  [ 1 11]]

# %%
print("The report:\n",clf_report)
# Out:
# The report:
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99        33
#            1       1.00      0.92      0.96        12
#
#     accuracy                           0.98        45
#    macro avg       0.99      0.96      0.97        45
# weighted avg       0.98      0.98      0.98        45

# %%
from sklearn.metrics import roc_auc_score

roc_auc_score(y_test,grid.predict_proba(X_test)[:,1])
# Out:
# 1.0

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.006956      0.000983         0.009831        0.001777       10
# 1        0.010631      0.003276         0.013125        0.003691       10
# 2        0.007276      0.001180         0.016117        0.005218       10
# 3        0.014224      0.015770         0.009249        0.001292       10
# 4        0.007892      0.002560         0.015481        0.011724       10
# 5        0.006609      0.000868         0.012137        0.003149       10
# 6        0.009440      0.009869         0.012531        0.002394       10
# 7        0.014349      0.016507         0.011840        0.001915       10
# 8        0.026580      0.034465         0.016824        0.009276      100
# 9        0.006470      0.000837         0.012571        0.001727      100
# 10       0.008839      0.002628         0.012421        0.004050      100
# 11       0.009394      0.005869         0.015215        0.004715      100
# 12       0.010848      0.003837         0.011485        0.003015      100
# 13       0.005978      0.001033         0.015112        0.012024      100
# 14       0.005883      0.001009         0.010886        0.002672      100
# 15       0.003809      0.000555         0.014417        0.008843      100
# 16       0.045373      0.015676         0.014638        0.008467     1000
# 17       0.006640      0.002148         0.007010        0.000510     1000
# 18       0.016170      0.009202         0.009608        0.004355     1000
# 19       0.006036      0.001419         0.017689        0.010087     1000
# 20       0.070625      0.038191         0.013059        0.006333     1000
# 21       0.007234      0.004757         0.007664        0.002007     1000
# 22       0.007179      0.001126         0.006981        0.001107     1000
# 23       0.009737      0.010729         0.014721        0.006888     1000
# 24       0.076093      0.044148         0.007621        0.002182     2000
# 25       0.005166      0.001593         0.011963        0.007099     2000
# 26       0.008956      0.003194         0.010567        0.006397     2000
# 27       0.007347      0.005246         0.009285        0.003117     2000
# 28       0.091138      0.049142         0.008106        0.002051     2000
# 29       0.004419      0.001215         0.007322        0.001338     2000
# 30       0.007441      0.002539         0.007783        0.001605     2000
# 31       0.004326      0.000304         0.006791        0.001114     2000
# 32       0.085697      0.034925         0.005262        0.001008     3000
# 33       0.003590      0.001118         0.006009        0.001161     3000
# 34       0.009680      0.003525         0.008489        0.002113     3000
# 35       0.003728      0.000907         0.007094        0.002298     3000
# 36       0.100145      0.044649         0.008592        0.002861     3000
# 37       0.003284      0.000915         0.005970        0.001126     3000
# 38       0.006376      0.001946         0.008035        0.002434     3000
# 39       0.004761      0.001834         0.007282        0.002032     3000
#
#    param_gamma param_kernel  \
# 0         auto       linear
# 1         auto          rbf
# 2         auto         poly
# 3         auto      sigmoid
# 4        scale       linear
# 5        scale          rbf
# 6        scale         poly
# 7        scale      sigmoid
# 8         auto       linear
# 9         auto          rbf
# 10        auto         poly
# 11        auto      sigmoid
# 12       scale       linear
# 13       scale          rbf
# 14       scale         poly
# 15       scale      sigmoid
# 16        auto       linear
# 17        auto          rbf
# 18        auto         poly
# 19        auto      sigmoid
# 20       scale       linear
# 21       scale          rbf
# 22       scale         poly
# 23       scale      sigmoid
# 24        auto       linear
# 25        auto          rbf
# 26        auto         poly
# 27        auto      sigmoid
# 28       scale       linear
# 29       scale          rbf
# 30       scale         poly
# 31       scale      sigmoid
# 32        auto       linear
# 33        auto          rbf
# 34        auto         poly
# 35        auto      sigmoid
# 36       scale       linear
# 37       scale          rbf
# 38       scale         poly
# 39       scale      sigmoid
#
#                                                params  split0_test_score  \
# 0      {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}           0.888889
# 1         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}           1.000000
# 2        {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}           0.888889
# 3     {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.719642
# 4     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}           0.888889
# 5        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}           1.000000
# 6       {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}           0.888889
# 7    {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.719642
# 8     {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.888889
# 9        {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}           1.000000
# 10      {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}           0.888889
# 11   {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.719642
# 12   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.888889
# 13      {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}           1.000000
# 14     {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}           0.888889
# 15  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.719642
# 16   {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           0.888889
# 17      {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}           1.000000
# 18     {'C': 1000, 'gamma': 'auto', 'kernel': 'poly'}           0.943915
# 19  {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.719642
# 20  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.888889
# 21     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}           1.000000
# 22    {'C': 1000, 'gamma': 'scale', 'kernel': 'poly'}           0.943915
# 23  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...           0.719642
# 24   {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}           0.888889
# 25      {'C': 2000, 'gamma': 'auto', 'kernel': 'rbf'}           1.000000
# 26     {'C': 2000, 'gamma': 'auto', 'kernel': 'poly'}           0.943915
# 27  {'C': 2000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.719642
# 28  {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'}           0.888889
# 29     {'C': 2000, 'gamma': 'scale', 'kernel': 'rbf'}           1.000000
# 30    {'C': 2000, 'gamma': 'scale', 'kernel': 'poly'}           0.943915
# 31  {'C': 2000, 'gamma': 'scale', 'kernel': 'sigmo...           0.719642
# 32   {'C': 3000, 'gamma': 'auto', 'kernel': 'linear'}           0.888889
# 33      {'C': 3000, 'gamma': 'auto', 'kernel': 'rbf'}           1.000000
# 34     {'C': 3000, 'gamma': 'auto', 'kernel': 'poly'}           0.943915
# 35  {'C': 3000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.719642
# 36  {'C': 3000, 'gamma': 'scale', 'kernel': 'linear'}           0.888889
# 37     {'C': 3000, 'gamma': 'scale', 'kernel': 'rbf'}           1.000000
# 38    {'C': 3000, 'gamma': 'scale', 'kernel': 'poly'}           0.943915
# 39  {'C': 3000, 'gamma': 'scale', 'kernel': 'sigmo...           0.719642
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0