# %% [markdown]
# LLM projects End-to-End for Social_Network_Ads.csv dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
#Loading the dataset
df = pd.read_csv("Salary_Data.csv")

# %%
#Preprocessing the data
X= df.iloc[:, :-1].values
y= df.iloc[:, -1].values

# %%
# Split the dataset into features and target variable
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

# %%
#plotting the results
plt.scatter(X_test, y_test, color='red', label='Actual')
plt.plot(X_test, y_pred, color='blue', label='Predicted')
plt.xlabel('X values')
plt.ylabel('Y values')
plt.title('Actual vs Predicted Values')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 #plotting the results
#       2 plt.scatter(X_test, y_test, color='red', label='Actual')
# ----> 3 plt.plot(X_test, y_pred, color='blue', label='Predicted')
#       4 plt.xlabel('X values')
#       5 plt.ylabel('Y values')
#
# NameError: name 'y_pred' is not defined

# %%
#Evaluating the model
regressor = LinearRegression()
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print("Mean Squared Error:", mse)
print("R-squared:", r2)
print("Predicted values:", y_pred)
print("Actual values:", y_test)
print("Coefficients:", regressor.coef_)
print("Intercept:", regressor.intercept_)
print("Accuracy Score:", accuracy_score(y_test, y_pred.round()))
print("Model Score:", regressor.score(X_test, y_test))
# Out:
# Mean Squared Error: 23370078.800832972
# R-squared: 0.9740993407213511
# Predicted values: [ 40817.78327049 123188.08258899  65154.46261459  63282.41035735
#  115699.87356004 108211.66453108 116635.89968866  64218.43648597
#   76386.77615802]
# Actual values: [ 37731. 122391.  57081.  63218. 116969. 109431. 112635.  55794.  83088.]
# Coefficients: [9360.26128619]
# Intercept: 26777.391341197625
# Accuracy Score: 0.0
# Model Score: 0.9740993407213511
