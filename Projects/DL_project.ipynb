# %% [markdown]
# # General DL Project
#
# ## Problem
# DL end-to-end pipeline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.metrics import accuracy_score, mean_squared_error

# Load dataset
df = pd.read_csv("house_price.csv")
df.head()
# Out:
#    sqft  bedrooms  bathrooms  age   price
# 0  2298         3          2   10  369562
# 1  2541         3          2   20  448140
# 2  1613         4          3   25  410593
# 3  2409         1          1   14  253868
# 4  2873         4          2   25  470996

# %%
# Basic preprocessing example
if 'failure' in df.columns:
    X = df.drop('failure', axis=1)
    y = df['failure']
    model = RandomForestClassifier()
else:
    X = df.iloc[:,:-1]
    y = df.iloc[:,-1]
    model = RandomForestRegressor()

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

model.fit(X_train,y_train)
pred = model.predict(X_test)

print("Done. Model trained successfully.")
# Out:
# Done. Model trained successfully.
