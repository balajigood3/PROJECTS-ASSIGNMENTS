# %% [markdown]
# # 1.ValueError

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(["Just one sentence."])

# %% [markdown]
# # 2.ImportError

# %%
# !pip install textblob
# Out:
# Requirement already satisfied: textblob in c:\Users\good4\AppData\Local\Programs\Python\Python312\Lib\site-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in c:\Users\good4\AppData\Local\Programs\Python\Python312\Lib\site-packages (from textblob) (3.9.2)
# Requirement already satisfied: click in c:\Users\good4\AppData\Local\Programs\Python\Python312\Lib\site-packages (from nltk>=3.9->textblob) (8.3.1)
# Requirement already satisfied: joblib in c:\Users\good4\AppData\Local\Programs\Python\Python312\Lib\site-packages (from nltk>=3.9->textblob) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\Users\good4\AppData\Local\Programs\Python\Python312\Lib\site-packages (from nltk>=3.9->textblob) (2026.1.15)
# Requirement already satisfied: tqdm in c:\Users\good4\AppData\Local\Programs\Python\Python312\Lib\site-packages (from nltk>=3.9->textblob) (4.67.3)
# Requirement already satisfied: colorama in c:\Users\good4\AppData\Local\Programs\Python\Python312\Lib\site-packages (from click->nltk>=3.9->textblob) (0.4.6)

# %%
from textblob import TextBlob
print(TextBlob("Great work!").sentiment)
# Out:
# Sentiment(polarity=1.0, subjectivity=0.75)

# %% [markdown]
# # 3.ValueError

# %%
from gensim import corpora, models  # Import the needed modules

# Sample data
texts = [["cat", "dog", "mouse"], ["dog", "lion"]]

# Create a dictionary
dictionary = corpora.Dictionary(texts)

# Convert documents to bag-of-words format
corpus = [dictionary.doc2bow(text) for text in texts]

# Train LDA model
lda = models.LdaModel(corpus=corpus, id2word=dictionary, num_topics=2)

# Print the topics
for idx, topic in lda.print_topics(-1):
    print(f"Topic {idx}: {topic}")
# Out:
# Topic 0: 0.322*"dog" + 0.265*"cat" + 0.261*"mouse" + 0.152*"lion"
# Topic 1: 0.348*"dog" + 0.313*"lion" + 0.172*"mouse" + 0.167*"cat"

# %% [markdown]
# # 4.AttributeError

# %%
from sklearn.feature_extraction.text import CountVectorizer
docs = ["Number one", "Number two"]
cv = CountVectorizer()
cv.fit_transform(docs)
# Out:
# <2x3 sparse matrix of type '<class 'numpy.int64'>'
# 	with 4 stored elements in Compressed Sparse Row format>

# %% [markdown]
# # 5.TypeError

# %%
from wordcloud import WordCloud
import pandas as pd

df = pd.DataFrame({'text': ['This is great', None]})
text = " ".join(df['text'].dropna())
wc = WordCloud().generate(text)

# %% [markdown]
# # 6.TypeError

# %%
from wordcloud import WordCloud
import pandas as pd
import matplotlib.pyplot as plt

# Create the DataFrame
df = pd.DataFrame({'text': ['This is great', None]})

# Combine non-null text
text = " ".join(df['text'].dropna())

# Generate word cloud
wc = WordCloud(background_color='white').generate(text)

# Display the word cloud
plt.figure(figsize=(8, 4))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')  # Hide axis
plt.title("Word Cloud Output", fontsize=16)
plt.show()
