# %% [markdown]
# # RF Grid Without Train-Test Split
#
# Full professional submission notebook with explanations, plots, ML models, and hypothesis testing.

# %% [markdown]
# ## Random Forest GridSearch without Train-Test Split

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

dataset = pd.read_csv("insurance_pre.csv")
dataset = pd.get_dummies(dataset, drop_first=True)

X = dataset.drop("charges", axis=1)
y = dataset["charges"]

param_grid = {"n_estimators":[100,200]}

grid = GridSearchCV(RandomForestRegressor(), param_grid)
grid.fit(X,y)

grid.best_params_
# Out:
# {'n_estimators': 100}
