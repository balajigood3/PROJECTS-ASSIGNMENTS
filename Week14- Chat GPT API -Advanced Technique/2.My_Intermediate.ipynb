# %%
import openai

client = openai.OpenAI(api_key="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")  # Replace with your actual API key

messages = []
system_msg = input("What type of chatbot would you like to create?\n")
messages.append({"role": "system", "content": system_msg})

print("Your new assistant is ready!")

while True:
    user_input = input()
    if user_input.lower() == "quit":
        break

    messages.append({"role": "user", "content": user_input})

    response = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=messages
    )

    reply = response.choices[0].message.content
    messages.append({"role": "assistant", "content": reply})

    print("\n" + reply + "\n")
# Out:
# What type of chatbot would you like to create?
#  Mental health Assistance
# Your new assistant is ready!
#  What Assistance
# There are several forms of assistance available for individuals struggling with mental health issues, including:
#
# 1. Therapy and Counseling: Professional therapists and counselors can provide support and guidance to individuals experiencing mental health challenges. This can be done through individual therapy, group therapy, or couples/family counseling.
#
# 2. Medication: In some cases, medication may be prescribed by a psychiatrist to help manage symptoms of mental health disorders such as depression, anxiety, or bipolar disorder.
#
# 3. Support Groups: Support groups bring together individuals who are facing similar mental health issues to share experiences, offer support, and learn coping strategies.
#
# ...

# %%
#Imports OpenAI Library → Used to interact with OpenAI’s API.
#Creates a Client → Uses an API key to authenticate with OpenAI.
#Takes System Input → Asks the user for chatbot type and saves it in messages.
#Starts a Chat Loop → Continuously takes user input until "quit" is entered.
#Sends Messages to OpenAI → Requests a response from the GPT model (gpt-3.5-turbo).
#Displays the Response → Prints the chatbot’s reply and saves it for context.

# %%
#This is a basic chatbot using OpenAI’s API. 
#It keeps chatting with the user until they type "quit", while maintaining conversation history for better responses.
