# %%
#Once you've installed Ollama manually, you can download and run LLaMA 3 inside Anaconda Prompt
#ollama --version (Check Ollama Installation)
#ollama pull llama3 ( Download llama3 Model)
#ollama run llama3 (Run llama3 Locally)

import ollama

response = ollama.chat(model="llama3",
                       messages=[{"role": "user",
                                  "content": "Give me 3 ideas for apps I could build with OpenAI APIs"}])

print(response['message']['content'])
# Out:
# What a great question! Here are three app ideas that leverage the power of OpenAI APIs:
#
# **1. Chatbot Tutor**
#
# Use OpenAI's API to create a chatbot tutor that helps students learn new concepts and subjects. The app would allow users to input their areas of study (e.g., math, science, programming) and receive conversational guidance from a knowledgeable AI assistant. The chatbot could:
#
# * Answer questions on specific topics
# * Provide step-by-step problem-solving guidance
# * Offer relevant resources and references
# * Adapt its responses based on user feedback and learning progress
#
# **2. Creative Writing Partner**
#
# Inspire creativity with an app that combines the power of OpenAI's text generation capabilities with human imagination. Users would input a prompt or theme, and the app would generate a starting point for their writing. Then, they could build upon the AI-generated text, using suggestions and ideas from OpenAI's API to:
#
# * Develop characters, plotlines, or settings
# * Explore different genres (e.g., fantasy, romance, sci-fi)
# * Refine their writing style with AI-assisted feedback
#
# **3. Personalized Language Learning Assistant**
#
# Create an app that leverages OpenAI's language understanding and generation capabilities to help learners improve their speaking skills. The app would:
#
# * Analyze users' existing language proficiency and goals
# * Generate interactive conversations, role-playing scenarios, or dialogues based on the user's interests and level of proficiency
# * Provide real-time corrections and suggestions for improvement
# * Offer culturally relevant examples and idioms to enhance language comprehension
#
# These ideas are just a starting point. OpenAI's APIs offer vast possibilities for innovative applications in areas like education, creativity, and communication. What idea sparks your interest?
