# %% [markdown]
# # L1 Language Models, the Chat Format and Tokens

# %% [markdown]
# ## Setup
# #### Load the API key and relevant Python libaries.
# In this course, we've provided some code that loads the OpenAI API key for you.

# %%
import os
import openai
openai.api_key  = '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'

#openai.api_key  = os.environ['OPENAI_API_KEY']

# %%
#!pip install google-generativeai

import google.generativeai as genai

genai.configure(api_key="AIzaSyBy2gS6epIqKNaOCcEliCzfRw6GvJsG9KQ")

def get_completion(prompt, model="gemini-2.5-flash"):
    model = genai.GenerativeModel(model)
    response = model.generate_content(prompt)
    return response.text

response = get_completion("What is the capital of France?")
print(response)
# Out:
# The capital of France is **Paris**.

# %% [markdown]
# ## Tokens

# %%
response = get_completion("Take the letters in lollipop \
and reverse them")
print(response)
# Out:
# Reversing the letters in "lollipop" gives you:
#
# **popillol**

# %% [markdown]
# "lollipop" in reverse should be "popillol"

# %%
response = get_completion("""Take the letters in \
l-o-l-l-i-p-o-p and reverse them""")

# %%
response
# Out:
# 'Reversing the letters in "lollipop" gives you:\n\n**popillol**'

# %% [markdown]
# ## Helper function (chat format)
# Here's the helper function we'll use in this course.

# %%
from google import genai

def get_completion_from_messages(messages,
                                 model="gemini-2.0-flash",
                                 temperature=0,
                                 max_tokens=500):

    # Create Gemini client
    client = genai.Client(api_key="AIzaSyCoAHbCgi4IkN7_LseKpjIQ6VTw_W66l3k")

    # Extract system instruction and user content
    system_instruction = None
    contents = []

    for msg in messages:
        if msg["role"] == "system":
            system_instruction = msg["content"]
        elif msg["role"] == "user":
            contents.append(msg["content"])

    # Generate response
    response = client.models.generate_content(
        model=model,
        contents=contents,
        config={
            "temperature": temperature,
            "max_output_tokens": max_tokens,
            "system_instruction": system_instruction
        }
    )

    return response.text

# %%
from google import genai

client = genai.Client(api_key="AIzaSyBy2gS6epIqKNaOCcEliCzfRw6GvJsG9KQ")

response = client.models.generate_content(
    model="gemini-2.0-flash",
    contents="Say hello in one sentence."
)

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[53], line 5
#       1 from google import genai
#       3 client = genai.Client(api_key="AIzaSyBy2gS6epIqKNaOCcEliCzfRw6GvJsG9KQ")
# ----> 5 response = client.models.generate_content(
#       6     model="gemini-2.0-flash",
#       7     contents="Say hello in one sentence."
#       8 )
#      10 print(response.text)
#
# File c:\Users\good4\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\genai\models.py:5227, in Models.generate_content(self, model, contents, config)
#    5225 while remaining_remote_calls_afc > 0:
#    5226   i += 1
# -> 5227   response = self._generate_content(
#    5228       model=model, contents=contents, config=parsed_config
#    5229   )
#    5231   function_map = _extra_utils.get_function_map(parsed_config)
#    5232   if not function_map:
#
# ...

# %%
# combined
messages =  [
{'role':'system',
 'content':"""You are an assistant who \
responds in the style of Dr Seuss. \
All your responses must be one sentence long."""},
{'role':'user',
 'content':"""write me a story about a happy carrot"""},
]
response = get_completion_from_messages(messages,
                                        temperature =1)
print(response)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[40], line 10
#       1 # combined
#       2 messages =  [
#       3 {'role':'system',
#       4  'content':"""You are an assistant who \
#    (...)      8  'content':"""write me a story about a happy carrot"""},
#       9 ]
# ---> 10 response = get_completion_from_messages(messages,
#      11                                         temperature =1)
#      12 print(response)
#
# Cell In[37], line 6, in get_completion_from_messages(messages, model, temperature, max_tokens)
#       1 def get_completion_from_messages(messages,
#       2                                  model="gpt-2.5-flash",
#       3                                  temperature=0,
#       4                                  max_tokens=500):
#       5     client = openai.OpenAI(api_key="AIzaSyCoAHbCgi4IkN7_LseKpjIQ6VTw_W66l3k")  # Pass API key explicitly
# ...

# %%
def get_completion_and_token_count(messages,
                                   model="gemini-2.5-flash",
                                   temperature=0,
                                   max_tokens=500):

    client = generative.generativeai(api_key="AIzaSyCoAHbCgi4IkN7_LseKpjIQ6VTw_W66l3k")  # Pass API key explicitly
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=temperature,
        max_tokens=max_tokens,
    )

    content = response.choices[0].message.content  # Updated way to access content

    token_dict = {
        'prompt_tokens': response.usage.prompt_tokens,  # Updated way to access token counts
        'completion_tokens': response.usage.completion_tokens,
        'total_tokens': response.usage.total_tokens,
    }

    return content, token_dict

# %%
messages = [
    {'role': 'system', 'content': "You are an assistant who responds in the style of Dr Seuss."},
    {'role': 'user', 'content': "Write me a very short poem about a happy carrot"}
]

response, token_dict = get_completion_and_token_count(messages)

print("Response:", response)
print("Token Usage:", token_dict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 6
#       1 messages = [
#       2     {'role': 'system', 'content': "You are an assistant who responds in the style of Dr Seuss."},
#       3     {'role': 'user', 'content': "Write me a very short poem about a happy carrot"}
#       4 ]
# ----> 6 response, token_dict = get_completion_and_token_count(messages)
#       8 print("Response:", response)
#       9 print("Token Usage:", token_dict)
#
# Cell In[54], line 6, in get_completion_and_token_count(messages, model, temperature, max_tokens)
#       1 def get_completion_and_token_count(messages,
#       2                                    model="gemini-2.5-flash",
#       3                                    temperature=0,
#       4                                    max_tokens=500):
# ...
