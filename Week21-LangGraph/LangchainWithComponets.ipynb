# %%
import os
from langchain.chat_models import ChatOpenAI
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from langchain.vectorstores import FAISS
from langchain.embeddings import OpenAIEmbeddings
from langchain.document_loaders import TextLoader
from langchain.chains.retrieval_qa.base import RetrievalQA
from langchain.agents import Tool, initialize_agent, AgentType
from langchain.tools import TavilySearchResults
from dotenv import load_dotenv
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 2
#       1 import os
# ----> 2 from langchain.chat_models import ChatOpenAI
#       3 from langchain.prompts import PromptTemplate
#       4 from langchain.chains import LLMChain
#
# ImportError: cannot import name 'ChatOpenAI' from 'langchain.chat_models' (c:\Users\good4\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain\chat_models\__init__.py)

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-4o-mini")
print("Success!")
# Out:
# Success!

# %%
# 🔐 Set API keys
load_dotenv(dotenv_path=".env")  
openai_api_key = os.getenv("OPENAI_API_KEY")
tavily_api_key = os.getenv("TAVILY_API_KEY")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # 🔐 Set API keys
# ----> 2 load_dotenv(dotenv_path=".env")
#       3 openai_api_key = os.getenv("OPENAI_API_KEY")
#       4 tavily_api_key = os.getenv("TAVILY_API_KEY")
#
# NameError: name 'load_dotenv' is not defined

# %%
# 🔸 1. LLM model
llm = ChatOpenAI(model="gpt-3.5-turbo", temperature=0)

# 🔸 2. PromptTemplate + LLMChain (basic)
prompt = PromptTemplate.from_template("Answer clearly: {question}")
qa_chain = LLMChain(llm=llm, prompt=prompt)

# 🔸 3. Load sample documents for RAG
loader = TextLoader("sample.txt")  # Create this file
documents = loader.load()

# 🔸 4. Embed and store in FAISS vector DB
embedding = OpenAIEmbeddings()
vectordb = FAISS.from_documents(documents, embedding)
retriever = vectordb.as_retriever()

# 🔸 5. RetrievalQA chain (RAG)
rag_chain = RetrievalQA.from_chain_type(llm=llm, retriever=retriever)

# 🔸 6. External Tool - Web Search
search_tool = Tool(
    name="Tavily Search",
    func=TavilySearchResults(max_results=3).run,
    description="Search the internet for additional information"
)

# 🔸 7. Wrap RAG and QA as tools
tools = [
    Tool(name="Simple QA", func=qa_chain.run, description="Answer with basic LLMChain"),
    Tool(name="RAG Search", func=rag_chain.run, description="Answer using document retrieval"),
    search_tool
]

# 🔸 8. Agent that chooses best tool
agent = initialize_agent(
    tools=tools,
    llm=llm,
    agent=AgentType.ZERO_SHOT_REACT_DESCRIPTION,
    verbose=True
)

# 🚀 9. Run it
query = "What is LangGraph in LangChain?"
print("\nUser Question:", query)
answer = agent.run(query)
print("\nFinal Answer:", answer)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 5
#       2 llm = ChatOpenAI(model="gpt-3.5-turbo", temperature=0)
#       4 # 🔸 2. PromptTemplate + LLMChain (basic)
# ----> 5 prompt = PromptTemplate.from_template("Answer clearly: {question}")
#       6 qa_chain = LLMChain(llm=llm, prompt=prompt)
#       8 # 🔸 3. Load sample documents for RAG
#
# NameError: name 'PromptTemplate' is not defined
